# %%
import pandas as pd
import pandera as pa

# %% [raw]
# pip install pandera

# %%
df = pd.read_csv('ocorrencia.csv', sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              52242               52242                INCIDENTE
# 1              45331               45331                 ACIDENTE
# 2              45333               45333                 ACIDENTE
# 3              45401               45401                 ACIDENTE
# 4              45407               45407                 ACIDENTE
# 5              52243               52243                INCIDENTE
# 6              50713               50713          INCIDENTE GRAVE
# 7              45334               45334                INCIDENTE
# 8              45391               45391                 ACIDENTE
# 9              52244               52244                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0           PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1              GUARULHOS            SP                 SBGR     2012-01-06
# 2                 VIAMÃO            RS                 ****     2012-01-06
# 3          SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4               SÃO SEPÉ            RS                 ****     2012-01-06
# 5                UBATUBA            SP                 ****     2012-01-06
# 6               CAMPINAS            SP                 SDAI     2012-01-07
# 7                  BELÉM            PA                 SBBE     2012-01-08
# 8  CONCEIÇÃO DAS ALAGOAS            MG                 ****     2012-01-08
# 9             UBERLÂNDIA            MG                 SBUL     2012-01-08
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0
# 4        16:30:00                    0
# 5        14:30:00                    0
# 6        18:15:00                    0
# 7        19:12:00                    0
# 8        16:00:00                    0
# 9        22:13:00                    0

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo_item": pa.Column(pa.Int, required=False),
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2)),
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9]):([0-5][0-9])?$'), nullable=True),
        "total_recomendacoes": pa.Column(pa.Int)
    }
)

# %%
schema.validate(df)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21680/994206330.py in <module>
# ----> 1 schema.validate(df)
#
# D:\Program_Files\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     517             return check_obj.pandera.add_schema(self)
#     518
# --> 519         return self._validate(
#     520             check_obj=check_obj,
#     521             head=head,
#
# D:\Program_Files\Anaconda3\lib\site-packages\pandera\schemas.py in _validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     691                 check_results.append(check_utils.is_table(result))
#     692             except errors.SchemaError as err:
# --> 693                 error_handler.collect_error("schema_component_check", err)
#     694             except errors.SchemaErrors as err:
#     695                 for schema_error_dict in err.schema_errors:
#
# D:\Program_Files\Anaconda3\lib\site-packages\pandera\error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# D:\Program_Files\Anaconda3\lib\site-packages\pandera\schemas.py in _validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     683         for schema_component in schema_components:
#     684             try:
# --> 685                 result = schema_component(
#     686                     df_to_validate,
#     687                     lazy=lazy,
#
# D:\Program_Files\Anaconda3\lib\site-packages\pandera\schemas.py in __call__(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    2036     ) -> Union[pd.DataFrame, pd.Series]:
#    2037         """Alias for ``validate`` method."""
# -> 2038         return self.validate(
#    2039             check_obj, head, tail, sample, random_state, lazy, inplace
#    2040         )
#
# D:\Program_Files\Anaconda3\lib\site-packages\pandera\schema_components.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     230                     )
#     231             else:
# --> 232                 validate_column(check_obj, column_name)
#     233
#     234         return check_obj
#
# D:\Program_Files\Anaconda3\lib\site-packages\pandera\schema_components.py in validate_column(check_obj, column_name)
#     203
#     204         def validate_column(check_obj, column_name):
# --> 205             super(Column, copy(self).set_name(column_name)).validate(
#     206                 check_obj,
#     207                 head,
#
# D:\Program_Files\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1994                 )
#    1995             except errors.SchemaError as err:
# -> 1996                 error_handler.collect_error("dataframe_check", err)
#    1997             except Exception as err:  # pylint: disable=broad-except
#    1998                 # catch other exceptions that may occur when executing the
#
# D:\Program_Files\Anaconda3\lib\site-packages\pandera\error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# D:\Program_Files\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1989             try:
#    1990                 check_results.append(
# -> 1991                     _handle_check_results(
#    1992                         self, check_index, check, check_obj, *check_args
#    1993                     )
#
# D:\Program_Files\Anaconda3\lib\site-packages\pandera\schemas.py in _handle_check_results(schema, check_index, check, check_obj, *check_args)
#    2391             warnings.warn(error_msg, UserWarning)
#    2392             return True
# -> 2393         raise errors.SchemaError(
#    2394             schema,
#    2395             check_obj,
#
# SchemaError: <Schema Column(name=ocorrencia_uf, type=DataType(str))> failed element-wise validator 0:
# <Check str_length: str_length(2, 2)>
# failure cases:
#    index failure_case
# 0   1099          ***
# 1   4728          ***

# %% [raw]
# df.dtypes
# df.ocorrencia_dia.dt.month
